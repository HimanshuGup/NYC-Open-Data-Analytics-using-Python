# %% [markdown]
# #Importing packages

# %%
import pymongo
import json
import pandas as pd

# For Database
from pymongo import MongoClient

# %%
#Connection with the database
connection = MongoClient('localhost', 27017)
db = connection.crime

#Handle collections
data = db.complaint

complaintData = data.find()

# %% [markdown]
# Fetching records from the data and making Data Frame

# %%
#fetching data and making data frame
data = db.complaint
complaint_df = pd.DataFrame(list(data.find()))

# %%
complaint_df.describe()
# Out:
#        :@computed_region_92fq_4b7q :@computed_region_efsh_h5xi  \
# count                          130                         130
# unique                          28                          42
# top                             42                       11605
# freq                            10                           8
#
#        :@computed_region_f5dn_yrer :@computed_region_sbqj_enih  \
# count                          130                         130
# unique                          35                          39
# top                             11                          34
# freq                            12                          10
#
#        :@computed_region_yeji_bk3q                       _id addr_pct_cd  \
# count                          130                      4000        4000
# unique                           4                      4000          77
# top                              5  5dc737f18a80f1c6109459d7          44
# ...

# %%
complaint_df.dtypes
# Out:
# :@computed_region_92fq_4b7q    object
# :@computed_region_efsh_h5xi    object
# :@computed_region_f5dn_yrer    object
# :@computed_region_sbqj_enih    object
# :@computed_region_yeji_bk3q    object
# _id                            object
# addr_pct_cd                    object
# boro_nm                        object
# cmplnt_fr_dt                   object
# cmplnt_fr_tm                   object
# cmplnt_num                     object
# cmplnt_to_dt                   object
# cmplnt_to_tm                   object
# crm_atpt_cptd_cd               object
# hadevelopt                     object
# housing_psa                    object
# juris_desc                     object
# jurisdiction_code              object
# ky_cd                          object
# lat_lon                        object
# latitude                       object
# law_cat_cd                     object
# loc_of_occur_desc              object
# longitude                      object
# ofns_desc                      object
# ...

# %% [markdown]
# Dropping columns which are useless and not required for the analysis. ( First 5 columns including 'id' )

# %%
complaint_df = complaint_df.drop([":@computed_region_92fq_4b7q",":@computed_region_efsh_h5xi",
                                 ":@computed_region_f5dn_yrer",":@computed_region_sbqj_enih",
                                 ":@computed_region_yeji_bk3q","_id"], axis=1)

# %%
complaint_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 35 columns):
# addr_pct_cd          4000 non-null object
# boro_nm              3908 non-null object
# cmplnt_fr_dt         4000 non-null object
# cmplnt_fr_tm         4000 non-null object
# cmplnt_num           4000 non-null object
# cmplnt_to_dt         2344 non-null object
# cmplnt_to_tm         2348 non-null object
# crm_atpt_cptd_cd     4000 non-null object
# hadevelopt           58 non-null object
# housing_psa          86 non-null object
# juris_desc           4000 non-null object
# jurisdiction_code    3908 non-null object
# ky_cd                4000 non-null object
# lat_lon              130 non-null object
# latitude             130 non-null object
# law_cat_cd           4000 non-null object
# loc_of_occur_desc    2716 non-null object
# longitude            130 non-null object
# ofns_desc            4000 non-null object
# parks_nm             20 non-null object
# ...

# %%
complaint_df.head()
# Out:
#   addr_pct_cd    boro_nm             cmplnt_fr_dt cmplnt_fr_tm cmplnt_num  \
# 0          48      BRONX  2019-09-30T00:00:00.000     02:00:00  825219244
# 1          40      BRONX  2019-09-30T00:00:00.000     13:00:00  219394661
# 2          18  MANHATTAN  2019-09-30T00:00:00.000     11:40:00  184671534
# 3         103     QUEENS  2019-09-30T00:00:00.000     14:00:00  660160752
# 4          67   BROOKLYN  2019-09-29T00:00:00.000     16:00:00  122768005
#
#               cmplnt_to_dt cmplnt_to_tm crm_atpt_cptd_cd hadevelopt  \
# 0  2019-09-30T00:00:00.000     03:30:00        COMPLETED        NaN
# 1  2019-09-30T00:00:00.000     14:00:00        COMPLETED        NaN
# 2  2019-09-30T00:00:00.000     11:45:00        COMPLETED        NaN
# 3  2019-09-30T00:00:00.000     14:01:00        COMPLETED        NaN
# 4  2019-09-29T00:00:00.000     18:00:00        COMPLETED        NaN
#
#   housing_psa  ... station_name susp_age_group susp_race susp_sex  \
# ...

# %% [markdown]
# Dropping some more columns as they are useless and contain lot of duplicates values

# %%
complaint_df = complaint_df.drop(["hadevelopt" ,"housing_psa"] , axis=1)

# %% [markdown]
# Replace NA values and fill with 'Not Applicable'

# %%
complaint_df["station_name"].fillna('Not Applicable' , inplace = True )

# %%
complaint_df["transit_district"].describe()
# Out:
# count       36
# unique       7
# top       11.0
# freq         8
# Name: transit_district, dtype: object

# %%
complaint_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 33 columns):
# addr_pct_cd          4000 non-null object
# boro_nm              3908 non-null object
# cmplnt_fr_dt         4000 non-null object
# cmplnt_fr_tm         4000 non-null object
# cmplnt_num           4000 non-null object
# cmplnt_to_dt         2344 non-null object
# cmplnt_to_tm         2348 non-null object
# crm_atpt_cptd_cd     4000 non-null object
# juris_desc           4000 non-null object
# jurisdiction_code    3908 non-null object
# ky_cd                4000 non-null object
# lat_lon              130 non-null object
# latitude             130 non-null object
# law_cat_cd           4000 non-null object
# loc_of_occur_desc    2716 non-null object
# longitude            130 non-null object
# ofns_desc            4000 non-null object
# parks_nm             20 non-null object
# patrol_boro          3908 non-null object
# pd_cd                3908 non-null object
# ...
